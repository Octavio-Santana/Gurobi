# %% [markdown]
# # Problema do Empacotamento
#
# Problema bastante importante na área de logistica, mais especficamente na área de armazenagem.
#
# Objetivo do problema é gaurdar todos os itens em caixas minimizando a quantidade de caixas necessárias.
#
# **Observação** Os itens não podem ser fracionados.
#
# Índices:
# - i = 1, ..., m itens;
# - j = 1, ..., n caixas;
#
# Parâmetroas:
# - $w_i$ peso do item i;
# - $C$ capacidade das caixas;
#
# Limitante inferior = $\left[\frac{\sum_{i=1}^{n}w_i}{C}\right]$. Corresponde uma estimativa de quanto que é o melhor caso possível para solução ótima.
#
# Limitante superior obtém pelo algoritmo ``next fit``.
#
#
# Variáveis de Decisão (todas binárias)
# - $x_{ij}$ indica se o item i será colocado na caixa j;
# - $y_j$ indica se a caixa j foi usada na solução;
#
# #### Função Objetivo
#
# $$
# \min\left[ \sum_{j=1}^{n}y_j \right]
# $$
#
# #### Função Restrição:
#
# restrição na capacidade da caixa
# $$
# \sum_{i=1}^{m}w_ix_{ij} \leq C y_{j}, \;\; \forall j=1, ..., n
# $$
#
# todos os itens devem estar em uma caixa
# $$
# \sum_{j=1}^{n}x_{ij} = 1, \;\; \forall i=1, ..., m
# $$

# %%
import gurobipy as gp

# %%
def calcula_qtd_caixas(itens, pesos, capacidade):
    """
    Calcula a quantidade de caixas usando o algoritmo ``first fit``
    """
    qtd_caixas = 1
    capacidade_usada = pesos[itens[0]]
    for item in itens[1:]:
        capacidade_usada += pesos[item]
        if capacidade_usada > capacidade:
            qtd_caixas += 1
            capacidade_usada = pesos[item]
    return qtd_caixas

def read_instancia(arq):
    with open(arq, 'r') as f:
        lines = f.readlines()
        # Ler a quantidade de itens e a capacidade da caixa
        qtd_itens, capacidade = [int(x) for x in lines[0].strip().split(' ')]
        # Gera os rótulos dos itens
        itens = [f'Item_{i}' for i in range(1, qtd_itens+1)]
        # Dicionário de pesos dos itens
        pesos = {itens[i]:int(peso) for i, peso in enumerate(lines[1].strip().split(' '))}
        # Rótulo das caixas
        qtd_caixas = calcula_qtd_caixas(itens, pesos, capacidade)
        caixas = [f'Caixa_{j}' for j in range(1,qtd_caixas+1)]
    return capacidade, itens, caixas, pesos

# %%
def solver(arq):
    # Lê os dados da instância
    capacidade, itens, caixas, pesos = read_instancia(arq)
    
    # Modelo
    m = gp.Model()

    # Variáveis de decisão
    x = m.addVars(itens, caixas, vtype=gp.GRB.BINARY)
    y = m.addVars(caixas, vtype=gp.GRB.BINARY)

    # Função Objetivo
    m.setObjective(
        gp.quicksum(y[j] for j in caixas),
        sense=gp.GRB.MINIMIZE
    )

    # Restrição de todos os itens em uma caixa
    c1 = m.addConstrs(
        gp.quicksum(x[i,j] for j in caixas) == 1 for i in itens
    )

    # Restrição de capacidade
    c2 = m.addConstrs(
        gp.quicksum(pesos[i]*x[i,j] for i in itens) <= capacidade*y[j] for j in caixas
    )

    # Executar o modelo
    m.setParam(gp.GRB.Param.OutputFlag, 0)   # Não imprimir o relatório.
    m.setParam(gp.GRB.Param.TimeLimit, 5)    # Tempo limite de execução do modelo com apenas '5 segundos'.    
    m.optimize()
    
    return m.objVal, m.Status

# %%
instancia = 'Empacotamento/inst_{:03d}.txt'
solucao = list()
for i in range(1,101):
    arq_inst = instancia.format(i)
    caixas, status = solver(arq_inst)
    solucao.append((caixas, status))
    print('Instância', i)
    #print(f"O solver encontrou uma solução com {caixas} caixas")
# Out:
# Using license file /home/octavio/gurobi.lic
# Academic license - for non-commercial use only
# Instância 1
# Instância 2
# Instância 3
# Instância 4
# Instância 5
# Instância 6
# Instância 7
# Instância 8
# Instância 9
# Instância 10
# Instância 11
# Instância 12
# Instância 13
# Instância 14
# Instância 15
# Instância 16
# Instância 17
# Instância 18
# Instância 19
# Instância 20
# Instância 21
# Instância 22
# Instância 23
# Instância 24
# Instância 25
# Instância 26
# Instância 27
# Instância 28
# Instância 29
# Instância 30
# Instância 31
# Instância 32
# Instância 33
# Instância 34
# Instância 35
# Instância 36
# Instância 37
# Instância 38
# Instância 39
# Instância 40
# Instância 41
# Instância 42
# Instância 43
# Instância 44
# Instância 45
# Instância 46
# Instância 47
# Instância 48
# Instância 49
# Instância 50
# Instância 51
# Instância 52
# Instância 53
# Instância 54
# Instância 55
# Instância 56
# Instância 57
# Instância 58
# Instância 59
# Instância 60
# Instância 61
# Instância 62
# Instância 63
# Instância 64
# Instância 65
# Instância 66
# Instância 67
# Instância 68
# Instância 69
# Instância 70
# Instância 71
# Instância 72
# Instância 73
# Instância 74
# Instância 75
# Instância 76
# Instância 77
# Instância 78
# Instância 79
# Instância 80
# Instância 81
# Instância 82
# Instância 83
# Instância 84
# Instância 85
# Instância 86
# Instância 87
# Instância 88
# Instância 89
# Instância 90
# Instância 91
# Instância 92
# Instância 93
# Instância 94
# Instância 95
# Instância 96
# Instância 97
# Instância 98
# Instância 99
# Instância 100

# %%
for idx, sol in enumerate(solucao, 1):
    caixa, status = sol
    if status == 2:
        print(f"Instânica {idx:03d}: Encontrou uma solução com {caixa} caixas - SOLUÇÃO ÓTIMA.")
    else:
        print(f"Instânica {idx:03d}: Encontrou uma solução com {caixa} caixas - TEMPO LIMITE.")
# Out:
# Instânica 001: Encontrou uma solução com 23.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 002: Encontrou uma solução com 75.0 caixas - TEMPO LIMITE.
# Instânica 003: Encontrou uma solução com 19.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 004: Encontrou uma solução com 52.0 caixas - TEMPO LIMITE.
# Instânica 005: Encontrou uma solução com 31.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 006: Encontrou uma solução com 22.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 007: Encontrou uma solução com 35.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 008: Encontrou uma solução com 35.0 caixas - TEMPO LIMITE.
# Instânica 009: Encontrou uma solução com 65.0 caixas - TEMPO LIMITE.
# Instânica 010: Encontrou uma solução com 59.0 caixas - TEMPO LIMITE.
# Instânica 011: Encontrou uma solução com 52.0 caixas - TEMPO LIMITE.
# Instânica 012: Encontrou uma solução com 13.0 caixas - TEMPO LIMITE.
# Instânica 013: Encontrou uma solução com 13.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 014: Encontrou uma solução com 19.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 015: Encontrou uma solução com 40.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 016: Encontrou uma solução com 62.0 caixas - TEMPO LIMITE.
# Instânica 017: Encontrou uma solução com 40.0 caixas - TEMPO LIMITE.
# Instânica 018: Encontrou uma solução com 75.0 caixas - TEMPO LIMITE.
# Instânica 019: Encontrou uma solução com 44.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 020: Encontrou uma solução com 77.0 caixas - TEMPO LIMITE.
# Instânica 021: Encontrou uma solução com 69.0 caixas - TEMPO LIMITE.
# Instânica 022: Encontrou uma solução com 75.0 caixas - TEMPO LIMITE.
# Instânica 023: Encontrou uma solução com 58.0 caixas - TEMPO LIMITE.
# Instânica 024: Encontrou uma solução com 63.0 caixas - TEMPO LIMITE.
# Instânica 025: Encontrou uma solução com 25.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 026: Encontrou uma solução com 51.0 caixas - TEMPO LIMITE.
# Instânica 027: Encontrou uma solução com 24.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 028: Encontrou uma solução com 75.0 caixas - TEMPO LIMITE.
# Instânica 029: Encontrou uma solução com 53.0 caixas - TEMPO LIMITE.
# Instânica 030: Encontrou uma solução com 13.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 031: Encontrou uma solução com 69.0 caixas - TEMPO LIMITE.
# Instânica 032: Encontrou uma solução com 63.0 caixas - TEMPO LIMITE.
# Instânica 033: Encontrou uma solução com 42.0 caixas - TEMPO LIMITE.
# Instânica 034: Encontrou uma solução com 81.0 caixas - TEMPO LIMITE.
# Instânica 035: Encontrou uma solução com 44.0 caixas - TEMPO LIMITE.
# Instânica 036: Encontrou uma solução com 9.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 037: Encontrou uma solução com 74.0 caixas - TEMPO LIMITE.
# Instânica 038: Encontrou uma solução com 66.0 caixas - TEMPO LIMITE.
# Instânica 039: Encontrou uma solução com 27.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 040: Encontrou uma solução com 42.0 caixas - TEMPO LIMITE.
# Instânica 041: Encontrou uma solução com 60.0 caixas - TEMPO LIMITE.
# Instânica 042: Encontrou uma solução com 35.0 caixas - TEMPO LIMITE.
# Instânica 043: Encontrou uma solução com 76.0 caixas - TEMPO LIMITE.
# Instânica 044: Encontrou uma solução com 35.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 045: Encontrou uma solução com 21.0 caixas - TEMPO LIMITE.
# Instânica 046: Encontrou uma solução com 29.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 047: Encontrou uma solução com 36.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 048: Encontrou uma solução com 20.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 049: Encontrou uma solução com 13.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 050: Encontrou uma solução com 81.0 caixas - TEMPO LIMITE.
# Instânica 051: Encontrou uma solução com 69.0 caixas - TEMPO LIMITE.
# Instânica 052: Encontrou uma solução com 56.0 caixas - TEMPO LIMITE.
# Instânica 053: Encontrou uma solução com 82.0 caixas - TEMPO LIMITE.
# Instânica 054: Encontrou uma solução com 61.0 caixas - TEMPO LIMITE.
# Instânica 055: Encontrou uma solução com 52.0 caixas - TEMPO LIMITE.
# Instânica 056: Encontrou uma solução com 38.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 057: Encontrou uma solução com 37.0 caixas - TEMPO LIMITE.
# Instânica 058: Encontrou uma solução com 49.0 caixas - TEMPO LIMITE.
# Instânica 059: Encontrou uma solução com 25.0 caixas - TEMPO LIMITE.
# Instânica 060: Encontrou uma solução com 37.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 061: Encontrou uma solução com 79.0 caixas - TEMPO LIMITE.
# Instânica 062: Encontrou uma solução com 13.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 063: Encontrou uma solução com 29.0 caixas - TEMPO LIMITE.
# Instânica 064: Encontrou uma solução com 53.0 caixas - TEMPO LIMITE.
# Instânica 065: Encontrou uma solução com 73.0 caixas - TEMPO LIMITE.
# Instânica 066: Encontrou uma solução com 88.0 caixas - TEMPO LIMITE.
# Instânica 067: Encontrou uma solução com 19.0 caixas - TEMPO LIMITE.
# Instânica 068: Encontrou uma solução com 15.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 069: Encontrou uma solução com 66.0 caixas - TEMPO LIMITE.
# Instânica 070: Encontrou uma solução com 75.0 caixas - TEMPO LIMITE.
# Instânica 071: Encontrou uma solução com 45.0 caixas - TEMPO LIMITE.
# Instânica 072: Encontrou uma solução com 31.0 caixas - TEMPO LIMITE.
# Instânica 073: Encontrou uma solução com 65.0 caixas - TEMPO LIMITE.
# Instânica 074: Encontrou uma solução com 51.0 caixas - TEMPO LIMITE.
# Instânica 075: Encontrou uma solução com 25.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 076: Encontrou uma solução com 74.0 caixas - TEMPO LIMITE.
# Instânica 077: Encontrou uma solução com 76.0 caixas - TEMPO LIMITE.
# Instânica 078: Encontrou uma solução com 29.0 caixas - TEMPO LIMITE.
# Instânica 079: Encontrou uma solução com 59.0 caixas - TEMPO LIMITE.
# Instânica 080: Encontrou uma solução com 9.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 081: Encontrou uma solução com 72.0 caixas - TEMPO LIMITE.
# Instânica 082: Encontrou uma solução com 53.0 caixas - TEMPO LIMITE.
# Instânica 083: Encontrou uma solução com 11.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 084: Encontrou uma solução com 81.0 caixas - TEMPO LIMITE.
# Instânica 085: Encontrou uma solução com 45.0 caixas - TEMPO LIMITE.
# Instânica 086: Encontrou uma solução com 44.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 087: Encontrou uma solução com 15.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 088: Encontrou uma solução com 69.0 caixas - TEMPO LIMITE.
# Instânica 089: Encontrou uma solução com 58.0 caixas - TEMPO LIMITE.
# Instânica 090: Encontrou uma solução com 36.0 caixas - TEMPO LIMITE.
# Instânica 091: Encontrou uma solução com 64.0 caixas - TEMPO LIMITE.
# Instânica 092: Encontrou uma solução com 10.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 093: Encontrou uma solução com 30.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 094: Encontrou uma solução com 49.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 095: Encontrou uma solução com 49.0 caixas - TEMPO LIMITE.
# Instânica 096: Encontrou uma solução com 12.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 097: Encontrou uma solução com 61.0 caixas - TEMPO LIMITE.
# Instânica 098: Encontrou uma solução com 43.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 099: Encontrou uma solução com 33.0 caixas - SOLUÇÃO ÓTIMA.
# Instânica 100: Encontrou uma solução com 83.0 caixas - TEMPO LIMITE.
